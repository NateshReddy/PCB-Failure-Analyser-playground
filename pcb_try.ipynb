# %% [markdown]
# <a href="https://colab.research.google.com/github/NateshReddy/PCB-Failure-Analyser-playground/blob/main/pcb_try.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/sean-mcclure/defect_classifier.git
# Out:
# Cloning into 'defect_classifier'...
# remote: Enumerating objects: 76, done.
# remote: Counting objects: 100% (76/76), done.
# remote: Compressing objects: 100% (60/60), done.
# remote: Total 882 (delta 20), reused 64 (delta 14), pack-reused 806
# Receiving objects: 100% (882/882), 247.22 MiB | 32.57 MiB/s, done.
# Resolving deltas: 100% (82/82), done.

# %%
import os
os.chdir("/content/drive/MyDrive/Project/defect_classifier/notebooks")

# %%
# !pip install git+https://github.com/sean-mcclure/tetryon_ai.git
# Out:
# ...
#   Cloning https://github.com/sean-mcclure/tetryon_ai.git to /tmp/pip-req-build-_qhegycw
#   Running command git clone -q https://github.com/sean-mcclure/tetryon_ai.git /tmp/pip-req-build-_qhegycw
# ...
#   Created wheel for tetryonai: filename=tetryonai-0.1-cp36-none-any.whl size=124683 sha256=debaad53036943c43b1c347b98fed130033c487ec0aca9c56964f9d1c8fc4eea
#   Stored in directory: /tmp/pip-ephem-wheel-cache-fqn3r631/wheels/c2/34/90/3a2ac8c14e96dda5ed60d10f55c74836508cdc6825141c4c03
# Successfully built tetryonai
# ...

# %%
from tetryonai.main import *

# %%
directory(**{
    "choice" : "make",
    "directory_path" : "difference_img"
})

directory(**{
    "choice" : "make",
    "directory_path" : "extracted_defects"
})

directory(**{
    "choice" : "make",
    "directory_path" : "hold_out"
})

# %%
# !git clone https://github.com/tangsanli5201/DeepPCB.git
# Out:
# Cloning into 'DeepPCB'...
# remote: Enumerating objects: 4753, done.
# remote: Total 4753 (delta 0), reused 0 (delta 0), pack-reused 4753
# Receiving objects: 100% (4753/4753), 85.81 MiB | 16.57 MiB/s, done.
# Resolving deltas: 100% (191/191), done.
# Checking out files: 100% (4548/4548), done.

# %%
import glob

image_path = 'DeepPCB/PCBData/'
temp_pattern = '/*temp.jpg'
test_pattern = '/*test.jpg'

temps_and_tests = {}

for folder in os.listdir(image_path):
    full_path = image_path + folder + '/' + folder.replace('group', '')
    temps = glob.glob(full_path + '/' + temp_pattern)
    tests = glob.glob(full_path + '/' + test_pattern)
    inner = {}
    inner['temps'] = temps
    inner['tests'] = tests
    temps_and_tests[folder] = inner

# %%
split_percentage = round(len(temps_and_tests['group00041']['temps']) * 0.2)

for index, whatever in enumerate(temps_and_tests['group00041']['temps']):
    root_img_name = temps_and_tests['group00041']['temps'][index].replace('_temp.jpg', '')
    temp_file_path = root_img_name  + '_temp.jpg'
    test_file_path = root_img_name + '_test.jpg'
    if(index < split_percentage):
      copy_files(**{
          "file_paths" : [temp_file_path],
          "target_directory" : "hold_out/"
      })
      copy_files(**{
          "file_paths" : [test_file_path],
          "target_directory" : "hold_out/"
      })
    else:
      subtract_images(**{
          "image_path_1" : temp_file_path,
          "image_path_2" : test_file_path,
          "write_path" : "difference_img/diff_image_" + str(index) + ".png"
      })

# %%
all_differenced_images = os.listdir('difference_img')

# %%
for index, filename in enumerate(all_differenced_images):
    os.mkdir("extracted_defects/extracts_" + str(index))
    this_write_path = "extracted_defects/extracts_" + str(index) + "/"
    extract_contours_from_image(**{
        "image_path" : "difference_img/" + filename,
        "write_path" : this_write_path,
        "hsv_lower" : [0,150,50],
        "hsv_upper" : [10,255,255]
    })
# Out:
# skipping image difference_img/diff_image_50.png
# skipping image difference_img/diff_image_54.png
# skipping image difference_img/diff_image_54.png
# skipping image difference_img/diff_image_54.png
# skipping image difference_img/diff_image_54.png
# skipping image difference_img/diff_image_54.png
# skipping image difference_img/diff_image_54.png
# skipping image difference_img/diff_image_54.png
# skipping image difference_img/diff_image_54.png
# skipping image difference_img/diff_image_54.png
# skipping image difference_img/diff_image_54.png
# skipping image difference_img/diff_image_61.png
# skipping image difference_img/diff_image_61.png
# skipping image difference_img/diff_image_61.png
# skipping image difference_img/diff_image_61.png
# skipping image difference_img/diff_image_61.png
# skipping image difference_img/diff_image_61.png
# skipping image difference_img/diff_image_61.png
# skipping image difference_img/diff_image_62.png
# skipping image difference_img/diff_image_66.png
# ...

# %%
directory(**{
    "choice" : "make",
    "directory_path" : "all_extracts"
})

# %%
cnt=0
for dirpath, dirs, files in os.walk("extracted_defects"):
    for index, filename in enumerate(files):
        if filename.endswith(".png"):
            cnt += 1            
            move_files(**{
                "file_paths" : [dirpath + "/" + filename],
                "target_directory" : "all_extracts/extract_" + str(cnt) + ".png"
            })

# %%
# !ls
# Out:
# all_extracts  difference_img	 hold_out
# DeepPCB       extracted_defects  PCB_Defect_Extraction_and_Classification.ipynb

# %%
# !zip -r /extracted_defects.zip all_extracts/
# Out:
#   adding: all_extracts/ (stored 0%)
#   adding: all_extracts/extract_1.png (stored 0%)
#   adding: all_extracts/extract_2.png (deflated 3%)
#   adding: all_extracts/extract_3.png (stored 0%)
#   adding: all_extracts/extract_4.png (deflated 5%)
#   adding: all_extracts/extract_5.png (deflated 7%)
#   adding: all_extracts/extract_6.png (deflated 7%)
#   adding: all_extracts/extract_7.png (deflated 6%)
#   adding: all_extracts/extract_8.png (deflated 31%)
#   adding: all_extracts/extract_9.png (deflated 22%)
#   adding: all_extracts/extract_10.png (deflated 3%)
#   adding: all_extracts/extract_11.png (deflated 4%)
#   adding: all_extracts/extract_12.png (deflated 14%)
#   adding: all_extracts/extract_13.png (deflated 8%)
#   adding: all_extracts/extract_14.png (deflated 8%)
#   adding: all_extracts/extract_15.png (deflated 6%)
#   adding: all_extracts/extract_16.png (deflated 33%)
#   adding: all_extracts/extract_17.png (deflated 16%)
# ...

# %%
import json

file_names_and_sizes = {}
file_names = os.listdir('all_extracts/')

for index, file in enumerate(file_names):
  file_names_and_sizes[file_names[index]] = os.path.getsize('all_extracts/' + file)

# %%
file_names_and_sizes = {k: v for k, v in file_names_and_sizes.items() if v != 0}

# %%
with open('extracted_defects.json', 'w') as outfile:
    json.dump(file_names_and_sizes, outfile)

# %%
# !pip install http://download.pytorch.org/whl/cpu/torch-1.0.0-cp36-cp36m-linux_x86_64.whl
# Out:
# ...
#      |████████████████████████████████| 69.4MB 1.1MB/s
# ERROR: torchvision 0.8.1+cu101 has requirement torch==1.7.0, but you'll have torch 1.0.0 which is incompatible.
# ...
#   Found existing installation: torch 1.7.0
#     Uninstalling torch-1.7.0:
#       Successfully uninstalled torch-1.7.0
# ...

# %%
# !pip install fastai

# %%
# !pip install torch

# %%
from fastai.vision import *
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-3-c0e76450f370> in <module>()
# ----> 1 from fastai.vision import *
#
# /usr/local/lib/python3.6/dist-packages/fastai/vision/__init__.py in <module>()
#       1 from .. import basics
#       2 from ..basics import *
# ----> 3 from .learner import *
#       4 from .image import *
#       5 from .data import *
#
# /usr/local/lib/python3.6/dist-packages/fastai/vision/learner.py in <module>()
#       4 from ..basic_data import *
#       5 from .image import *
# ----> 6 from . import models
#       7 from ..callback import *
#       8 from ..layers import *
#
# /usr/local/lib/python3.6/dist-packages/fastai/vision/models/__init__.py in <module>()
#       1 from .xresnet import *
# ----> 2 from torchvision.models import ResNet,resnet18,resnet34,resnet50,resnet101,resnet152
# ...

# %%
# !pip install torch, torchvision
# Out:
# ...
#   Using cached https://files.pythonhosted.org/packages/80/2a/58f8078744e0408619c63148f7a2e8e48cf007e4146b74d4bb67c56d161b/torch-1.7.0-cp36-cp36m-manylinux1_x86_64.whl
# ...
#   Found existing installation: torch 1.0.0
#     Uninstalling torch-1.0.0:
#       Successfully uninstalled torch-1.0.0
# ...

# %%
# !pip install  torchvision==0.8.0
# Out:
# ...
#      |████████████████████████████████| 11.8MB 13.1MB/s
# ...
#   Using cached https://files.pythonhosted.org/packages/80/2a/58f8078744e0408619c63148f7a2e8e48cf007e4146b74d4bb67c56d161b/torch-1.7.0-cp36-cp36m-manylinux1_x86_64.whl
# ...
#   Found existing installation: torch 1.7.1
#     Uninstalling torch-1.7.1:
#       Successfully uninstalled torch-1.7.1
#   Found existing installation: torchvision 0.8.2
#     Uninstalling torchvision-0.8.2:
#       Successfully uninstalled torchvision-0.8.2
# ...

# %%
import torchvision
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-5-6dd351122000> in <module>()
# ----> 1 import torchvision
#
# /usr/local/lib/python3.6/dist-packages/torchvision/__init__.py in <module>()
#       2 import os
#       3
# ----> 4 from .extension import _HAS_OPS
#       5
#       6 from torchvision import models
#
# /usr/local/lib/python3.6/dist-packages/torchvision/extension.py in <module>()
#      99
#     100
# --> 101 _check_cuda_version()
#
# /usr/local/lib/python3.6/dist-packages/torchvision/extension.py in _check_cuda_version()
#      95                                "PyTorch has CUDA Version={}.{} and torchvision has CUDA Version={}.{}. "
#      96                                "Please reinstall the torchvision that matches your PyTorch install."
# ---> 97                                .format(t_major, t_minor, tv_major, tv_minor))
# ...

# %%
print(torch.__version__)
print(torchvision.__version__)
# Out:
# 1.7.0
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-132b64be65c1> in <module>()
#       1 print(torch.__version__)
# ----> 2 print(torchvision.__version__)
#
# NameError: name 'torchvision' is not defined
